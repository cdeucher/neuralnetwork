# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
##https://machinelearningmastery.com/keras-functional-api-deep-learning/
visible = Input(shape=(2,))
hidden1 = Dense(2, activation='tanh')(visible)
hidden2 = Dense(4, activation='tanh')(hidden1)
hidden3 = Dense(4, activation='tanh')(hidden2)
output = Dense(1, activation='sigmoid')(hidden3)
model = Model(inputs=visible, outputs=output)

# summarize layers
print(model.summary())
# plot graph
plot_model(model, to_file='multilayer_perceptron_graph.png')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 12
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 5
# ...
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from IPython.display import display
from PIL import Image

display(Image.open('multilayer_perceptron_graph.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=179x449 at 0x22860B31358>

# %%
x = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([[0], [1], [1], [1]])

# %%
#https://keras.io/optimizers/
sgd = 'rmsprop' #optimizers.SGD(lr=0.1, clipnorm=1.) #'sgd' #
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.fit(x, y, epochs=500, batch_size=1)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 0s 69ms/step - loss: 0.7043 - acc: 0.2500
# Epoch 2/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7001 - acc: 0.2500
# Epoch 3/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6976 - acc: 0.2500
# Epoch 4/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6956 - acc: 0.2500
# Epoch 5/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6938 - acc: 0.2500
# Epoch 6/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6921 - acc: 0.5000
# Epoch 7/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6905 - acc: 0.7500
# Epoch 8/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6889 - acc: 0.7500
# Epoch 9/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6875 - acc: 0.7500
# Epoch 10/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6859 - acc: 0.7500
# Epoch 11/500
# ...

# %%
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 4/4 [==============================] - 0s 15ms/step
# Accuracy: 100.00

# %%
test = np.array([[0,0], [0,1], [1,0], [1,1]])
predictions = model.predict(test)
rounded = [x for x in predictions]

for i in range(len(rounded)):
    print(rounded[i])
# Out:
# [0.00457555]
# [0.99740577]
# [0.9977646]
# [0.9980131]
# [[0.]
#  [1.]
#  [1.]
#  [1.]]

# %%
for i in range(4):
    print('%s => %d (expected %d)' % (x[i].tolist(), np.round(predictions[i]), y[i]))
# Out:
# [0, 0] => 0 (expected 0)
# [0, 1] => 1 (expected 1)
# [1, 0] => 1 (expected 1)
# [1, 1] => 1 (expected 1)
